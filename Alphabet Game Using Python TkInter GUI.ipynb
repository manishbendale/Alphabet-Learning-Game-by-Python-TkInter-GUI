# %%
from tkinter import *
import pygame
import pyttsx3

pygame.init()
engine = pyttsx3.init()
root = Tk()
root.title("Alphabet Application")
root.geometry("1352x652+0+0") ## = width x height + x + y
root.config(background = 'white')

str1 = StringVar()
str1.set("Welcome to Learning Game by Manish")
frame1 = Frame(root, bg = 'white')
frame1.grid()

#----- Clear Button----
imgClear=PhotoImage(file="my.png")
def Clear():
    str1.set("Welcome to Learning Game by Manish")
    image=Disp.create_image(270,250, image=imgClear)
    engine.say("Welcome to Learning Game By Manish")
    engine.runAndWait()
#---------------------------    

imgA = PhotoImage(file='a.png')
imgB = PhotoImage(file='b.png')
imgC = PhotoImage(file='c.png')
imgD = PhotoImage(file='d.png')
imgE = PhotoImage(file='e.png')
imgF = PhotoImage(file='f.png')
imgG = PhotoImage(file='g.png')
imgH = PhotoImage(file='h.png')
imgI = PhotoImage(file='i.png')
imgJ = PhotoImage(file='j.png')
imgK = PhotoImage(file='k.png')
imgL = PhotoImage(file='l.png')
imgM = PhotoImage(file='m.png')
imgN = PhotoImage(file='n.png')
imgO = PhotoImage(file='o.png')
imgP = PhotoImage(file='p.png')
imgQ = PhotoImage(file='q.png')
imgR = PhotoImage(file='r.png')
imgS = PhotoImage(file='s.png')
imgT = PhotoImage(file='t.png')
imgU = PhotoImage(file='u.png')
imgV = PhotoImage(file='v.png')
imgW = PhotoImage(file='w.png')
imgX = PhotoImage(file='x.png')
imgY = PhotoImage(file='y.png')
imgZ = PhotoImage(file='z.png')

def Alphabet_A():
    str1.set("A is for Apple")
    image=Disp.create_image(270,250, image=imgA)
    engine.say("A is for Apple")
    engine.runAndWait()
    
def Alphabet_B():
    str1.set("B is for Bear")
    image=Disp.create_image(270,250, image=imgB)
    engine.say("B is for Bear")
    engine.runAndWait()
    
def Alphabet_C():
    str1.set("C is for Cow")
    image=Disp.create_image(270,250, image=imgC)
    engine.say("C is for Cow")
    engine.runAndWait()
    
def Alphabet_D():
    str1.set("D is for Duck")
    image=Disp.create_image(270,250, image=imgD)
    engine.say("D is for Duck")
    engine.runAndWait()
    
def Alphabet_E():
    str1.set("E is for Elephant")
    image=Disp.create_image(270,250, image=imgE)
    engine.say("E is for Elephant")
    engine.runAndWait()
    
def Alphabet_F():
    str1.set("F is for Fish")
    image=Disp.create_image(270,250, image=imgF)
    engine.say("F is for Fish")
    engine.runAndWait()
    
def Alphabet_G():
    str1.set("G is for Goat")
    image=Disp.create_image(270,250, image=imgG)
    engine.say("G is for Goat")
    engine.runAndWait()
    
def Alphabet_H():
    str1.set("H is for Horse")
    image=Disp.create_image(270,250, image=imgH)
    engine.say("H is for Horse")
    engine.runAndWait()
    
def Alphabet_I():
    str1.set("I is for Ice-cream")
    image=Disp.create_image(270,250, image=imgI)
    engine.say("I is for Ice-cream")
    engine.runAndWait()
    
def Alphabet_J():
    str1.set("J is for Joker")
    image=Disp.create_image(270,250, image=imgJ)
    engine.say("J is for Joker")
    engine.runAndWait()
    
def Alphabet_K():
    str1.set("K is for kangaroo")
    image=Disp.create_image(270,250, image=imgK)
    engine.say("K is for Kangaroo")
    engine.runAndWait()
    
def Alphabet_L():
    str1.set("L is for Lion")
    image=Disp.create_image(270,250, image=imgL)
    engine.say("L is for Lion")
    engine.runAndWait()
    
def Alphabet_M():
    str1.set("M is for Monkey")
    image=Disp.create_image(270,250, image=imgM)
    engine.say("M is for Monkey")
    engine.runAndWait()
    
def Alphabet_N():
    str1.set("N is for Nilgai")
    image=Disp.create_image(270,250, image=imgN)
    engine.say("N is for Nilgai")
    engine.runAndWait()
    
def Alphabet_O():
    str1.set("O is for Orange")
    image=Disp.create_image(270,250, image=imgO)
    engine.say("O is for Orange")
    engine.runAndWait()
    
def Alphabet_P():
    str1.set("P is for Parrot")
    image=Disp.create_image(270,250, image=imgP)
    engine.say("P is for Parrot")
    engine.runAndWait()
    
def Alphabet_Q():
    str1.set("Q is for Queen")
    image=Disp.create_image(270,250, image=imgQ)
    engine.say("Q is for Queen")
    engine.runAndWait()
    
def Alphabet_R():
    str1.set("R is for Rabbit")
    image=Disp.create_image(270,250, image=imgR)
    engine.say("R is for Rabbit")
    engine.runAndWait()
    
def Alphabet_S():
    str1.set("S is for Sunflower")
    image=Disp.create_image(270,250, image=imgS)
    engine.say("S is for Sunflower")
    engine.runAndWait()
    
def Alphabet_T():
    str1.set("T is for Tiger")
    image=Disp.create_image(270,250, image=imgT)
    engine.say("T is for Tiger")
    engine.runAndWait()
    
def Alphabet_U():
    str1.set("U is for Umbrela")
    image=Disp.create_image(270,250, image=imgU)
    engine.say("U is for Umbrela")
    engine.runAndWait()
    
def Alphabet_V():
    str1.set("V is for Van")
    image=Disp.create_image(270,250, image=imgV)
    engine.say("V is for Van")
    engine.runAndWait()
    
def Alphabet_W():
    str1.set("W is for Watch")
    image=Disp.create_image(270,250, image=imgW)
    engine.say("W is for Watch")
    engine.runAndWait()
    
def Alphabet_X():
    str1.set("X is for Xmas")
    image=Disp.create_image(270,250, image=imgX)
    engine.say("X is for Xmas")
    engine.runAndWait()
    
def Alphabet_Y():
    str1.set("Y is for Yalk")
    image=Disp.create_image(270,250, image=imgY)
    engine.say("Y is for Yalk")
    engine.runAndWait()
    
def Alphabet_Z():
    str1.set("Z is for Zebra")
    image=Disp.create_image(270,250, image=imgZ)
    engine.say("Z is for Zebra")
    engine.runAndWait()

#=================   Main Screen =================
Display = Entry(frame1, textvariable = str1, 
                font = ('arial', 44, 'bold'),
                bg = 'blue', fg='white', 
                bd = 34, width=39, 
                justify=CENTER)
Display.grid(row=0, column=0, columnspan=7,pady=1)

#=================   Image Screen =================
Disp = Canvas(frame1, width=550, height=500, bg='white')
Disp.grid(row=1, column=0,rowspan=7, columnspan=3,pady=1)
img=PhotoImage(file='my.png')
image=Disp.create_image(270,250, image=img)

#=================  row1 =============

btnA = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_A,
              width = 10, height=1, 
              text='A', bg='Brown',
              fg='white').grid(row=1,column=3)

btnB = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_B,
              width = 10, height=1, 
              text='B', bg='Brown',
              fg='white').grid(row=1,column=4)

btnC = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_C,
              width = 10, height=1, 
              text='C', bg='Brown',
              fg='white').grid(row=1,column=5)

btnD = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_D,
              width = 10, height=1, 
              text='D', bg='Brown',
              fg='white').grid(row=1,column=6)

#=================  row2 =============

btnE = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_E,
              width = 10, height=1, 
              text='E', bg='Brown',
              fg='white').grid(row=2,column=3)

btnF = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_F,
              width = 10, height=1, 
              text='F', bg='#169c88',
              fg='white').grid(row=2,column=4)

btnG = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_G,
              width = 10, height=1, 
              text='G', bg='#169c88',
              fg='white').grid(row=2,column=5)

btnH = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_H,
              width = 10, height=1, 
              text='H', bg='Brown',
              fg='white').grid(row=2,column=6)

#=================  row3 =============

btnI = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_I,
              width = 10, height=1, 
              text='I', bg='Brown',
              fg='white').grid(row=3,column=3)

btnJ = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_J,
              width = 10, height=1, 
              text='J', bg='#169c88',
              fg='white').grid(row=3,column=4)

btnK = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_K,
              width = 10, height=1, 
              text='K', bg='#169c88',
              fg='white').grid(row=3,column=5)

btnL = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_L,
              width = 10, height=1, 
              text='L', bg='Brown',
              fg='white').grid(row=3,column=6)

#=================  row4 =============

btnM = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_M,
              width = 10, height=1, 
              text='M', bg='Brown',
              fg='white').grid(row=4,column=3)

btnN = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_N,
              width = 10, height=1, 
              text='N', bg='#169c88',
              fg='white').grid(row=4,column=4)

btnO = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_O,
              width = 10, height=1, 
              text='O', bg='#169c88',
              fg='white').grid(row=4,column=5)

btnP = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_P,
              width = 10, height=1, 
              text='P', bg='Brown',
              fg='white').grid(row=4,column=6)

#=================  row5 =============

btnQ = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_Q,
              width = 10, height=1, 
              text='Q', bg='Brown',
              fg='white').grid(row=5,column=3)

btnR = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_R,
              width = 10, height=1, 
              text='R', bg='#169c88',
              fg='white').grid(row=5,column=4)

btnS = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_S,
              width = 10, height=1, 
              text='S', bg='#169c88',
              fg='white').grid(row=5,column=5)

btnT = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_T,
              width = 10, height=1, 
              text='T', bg='Brown',
              fg='white').grid(row=5,column=6)

#=================  row6 =============

btnU = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_U,
              width = 10, height=1, 
              text='U', bg='Brown',
              fg='white').grid(row=6,column=3)

btnV = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_V,
              width = 10, height=1, 
              text='V', bg='#169c88',
              fg='white').grid(row=6,column=4)

btnW = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'), 
              command = Alphabet_W,
              width = 10, height=1, 
              text='W', bg='#169c88',
              fg='white').grid(row=6,column=5)

btnX = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_X,
              width = 10, height=1, 
              text='X', bg='Brown',
              fg='white').grid(row=6,column=6)

#=================  row7 =============

btnY = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_Y,
              width = 10, height=1, 
              text='Y', bg='Brown',
              fg='white').grid(row=7,column=3)

btnZ = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Alphabet_Z,
              width = 10, height=1, 
              text='Z', bg='#169c88',
              fg='white').grid(row=7,column=4)

btnClear = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = Clear,
              width = 10, height=1, 
              text='Clear', bg='green',
              fg='white').grid(row=7,column=5)

btnExit = Button(frame1, pady=1, bd=4, 
              font=('arial',21,'bold'),
              command = root.destroy,
              width = 10, height=1, 
              text='Exit', bg='red',
              fg='white').grid(row=7,column=6)

root.mainloop()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
